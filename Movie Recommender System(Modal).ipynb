# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from surprise import Reader, Dataset, SVD, evaluate

# %%
md = pd.read_csv('the-movies-dataset/movies_metadata.csv')
md.head().transpose()
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                        0  \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.9469
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# production_companies      [{'name': 'Pixar Animation Studios', 'id': 3}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-10-30
# revenue                                                      3.73554e+08
# runtime                                                               81
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                          Toy Story
# video                                                              False
# vote_average                                                         7.7
# vote_count                                                          5415
#
#                                                                        1  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                             NaN
# id                                                                  8844
# imdb_id                                                        tt0113497
# original_language                                                     en
# original_title                                                   Jumanji
# overview               When siblings Judy and Peter discover an encha...
# popularity                                                       17.0155
# poster_path                             /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# production_companies   [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-15
# revenue                                                      2.62797e+08
# runtime                                                              104
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                        Roll the dice and unleash the excitement!
# title                                                            Jumanji
# video                                                              False
# vote_average                                                         6.9
# vote_count                                                          2413
#
#                                                                        2  \
# adult                                                              False
# belongs_to_collection  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                 0
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                             NaN
# id                                                                 15602
# imdb_id                                                        tt0113228
# original_language                                                     en
# original_title                                          Grumpier Old Men
# overview               A family wedding reignites the ancient feud be...
# popularity                                                       11.7129
# poster_path                             /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                                0
# runtime                                                              101
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# video                                                              False
# vote_average                                                         6.5
# vote_count                                                            92
#
#                                                                        3  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          16000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                                             NaN
# id                                                                 31357
# imdb_id                                                        tt0114885
# original_language                                                     en
# original_title                                         Waiting to Exhale
# overview               Cheated on, mistreated and stepped on, the wom...
# popularity                                                       3.85949
# poster_path                             /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# production_companies   [{'name': 'Twentieth Century Fox Film Corporat...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                      8.14522e+07
# runtime                                                              127
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Friends are the people who let you be yourself...
# title                                                  Waiting to Exhale
# video                                                              False
# vote_average                                                         6.1
# vote_count                                                            34
#
#                                                                        4
# adult                                                              False
# belongs_to_collection  {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                 0
# genres                                    [{'id': 35, 'name': 'Comedy'}]
# homepage                                                             NaN
# id                                                                 11862
# imdb_id                                                        tt0113041
# original_language                                                     en
# original_title                               Father of the Bride Part II
# overview               Just when George Banks has recovered from his ...
# popularity                                                       8.38752
# poster_path                             /e64sOI48hQXyru7naBFyssKFxVd.jpg
# production_companies   [{'name': 'Sandollar Productions', 'id': 5842}...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-02-10
# revenue                                                      7.65789e+07
# runtime                                                              106
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Just When His World Is Back To Normal... He's ...
# title                                        Father of the Bride Part II
# video                                                              False
# vote_average                                                         5.7
# vote_count                                                           173

# %%
md['genres'] = md['genres'].fillna('[]').apply(ast.literal_eval)
md['genres'] = md['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else [])
md['genres'].head()
# Out:
# 0     [Animation, Comedy, Family]
# 1    [Adventure, Fantasy, Family]
# 2               [Romance, Comedy]
# 3        [Comedy, Drama, Romance]
# 4                        [Comedy]
# Name: genres, dtype: object

# %%
md['vote_count'].quantile(0.95)
# Out:
# 434.0

# %%
vote_count = md[md['vote_count'].notnull()]['vote_count'].astype('int')
vote_average = md[md['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_average.mean()
C
# Out:
# 5.244896612406511

# %%
m = vote_count.quantile(0.95)

# %%
md['year'] = pd.to_datetime(md['release_date'],errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
qualified = md[(md['vote_count'] > m) & (md['vote_count'].notnull()) &( md['vote_average'].notnull())][['title','year','vote_count','vote_average','popularity','genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape
# Out:
# (2268, 6)

# %%
def weighted_rating(x):
    v = x['vote_count']
    r = x['vote_average']
    wr = ((v/(v+m))*r) + ((m/(m+v))*C)
    return wr

# %%
qualified['wr'] = qualified.apply(weighted_rating,axis=1)

# %%
qualified = qualified.sort_values('wr',ascending=False).head(250)
qualified.head(25)
# Out:
#                                                    title  year  vote_count  \
# 15480                                          Inception  2010       14075
# 12481                                    The Dark Knight  2008       12269
# 22879                                       Interstellar  2014       11187
# 2843                                          Fight Club  1999        9678
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 292                                         Pulp Fiction  1994        8670
# 314                             The Shawshank Redemption  1994        8358
# 7000       The Lord of the Rings: The Return of the King  2003        8226
# 351                                         Forrest Gump  1994        8147
# 5814               The Lord of the Rings: The Two Towers  2002        7641
# 256                                            Star Wars  1977        6778
# 1225                                  Back to the Future  1985        6239
# 834                                        The Godfather  1972        6024
# 1154                             The Empire Strikes Back  1980        5998
# 46                                                 Se7en  1995        5915
# 24860                                 The Imitation Game  2014        5895
# 359                                        The Lion King  1994        5520
# 18465                                   The Intouchables  2011        5410
# 22841                           The Grand Budapest Hotel  2014        4644
# 586                             The Silence of the Lambs  1991        4549
# 11354                                       The Prestige  2006        4510
# 522                                     Schindler's List  1993        4436
# 23673                                           Whiplash  2014        4376
# 289                               Leon: The Professional  1994        4293
# 4099                                             Memento  2000        4168
#
#        vote_average popularity  \
# 15480             8    29.1081
# 12481             8    123.167
# 22879             8    32.2135
# 2843              8    63.8696
# 4863              8    32.0707
# 292               8     140.95
# 314               8    51.6454
# 7000              8    29.3244
# 351               8    48.3072
# 5814              8    29.4235
# 256               8    42.1497
# 1225              8    25.7785
# 834               8    41.1093
# 1154              8     19.471
# 46                8    18.4574
# 24860             8    31.5959
# 359               8    21.6058
# 18465             8    16.0869
# 22841             8     14.442
# 586               8    4.30722
# 11354             8    16.9456
# 522               8    41.7251
# 23673             8       64.3
# 289               8    20.4773
# 4099              8    15.4508
#
#                                                   genres        wr
# 15480  [Action, Thriller, Science Fiction, Mystery, A...  7.917588
# 12481                   [Drama, Action, Crime, Thriller]  7.905871
# 22879                [Adventure, Drama, Science Fiction]  7.897107
# 2843                                             [Drama]  7.881753
# 4863                        [Adventure, Fantasy, Action]  7.871787
# 292                                    [Thriller, Crime]  7.868660
# 314                                       [Drama, Crime]  7.864000
# 7000                        [Adventure, Fantasy, Action]  7.861927
# 351                             [Comedy, Drama, Romance]  7.860656
# 5814                        [Adventure, Fantasy, Action]  7.851924
# 256                 [Adventure, Action, Science Fiction]  7.834205
# 1225        [Adventure, Comedy, Science Fiction, Family]  7.820813
# 834                                       [Drama, Crime]  7.814847
# 1154                [Adventure, Action, Science Fiction]  7.814099
# 46                            [Crime, Mystery, Thriller]  7.811669
# 24860                    [History, Drama, Thriller, War]  7.811074
# 359                           [Family, Animation, Drama]  7.799175
# 18465                                    [Drama, Comedy]  7.795394
# 22841                                    [Comedy, Drama]  7.764530
# 586                             [Crime, Drama, Thriller]  7.760041
# 11354                         [Drama, Mystery, Thriller]  7.758148
# 522                                [Drama, History, War]  7.754473
# 23673                                            [Drama]  7.751411
# 289                             [Thriller, Crime, Drama]  7.747046
# 4099                                 [Mystery, Thriller]  7.740175

# %%
s = md.apply(lambda x: pd.Series(x['genres']),axis=1).stack().reset_index(level=1,drop=True)
s.name = 'genre'
gen_md = md.drop('genres',axis=1).join(s)

# %%
gen_md
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 1      False                                                NaN  65000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 3      False                                                NaN  16000000
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# 5      False                                                NaN  60000000
# 5      False                                                NaN  60000000
# 5      False                                                NaN  60000000
# 6      False                                                NaN  58000000
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 7      False                                                NaN         0
# 7      False                                                NaN         0
# 7      False                                                NaN         0
# 8      False                                                NaN  35000000
# 8      False                                                NaN  35000000
# 8      False                                                NaN  35000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10     False                                                NaN  62000000
# 10     False                                                NaN  62000000
# ...      ...                                                ...       ...
# 45450  False                                                NaN         0
# 45450  False                                                NaN         0
# 45450  False                                                NaN         0
# 45451  False                                                NaN         0
# 45451  False                                                NaN         0
# 45452  False                                                NaN         0
# 45453  False                                                NaN         0
# 45453  False                                                NaN         0
# 45453  False                                                NaN         0
# 45454  False                                                NaN         0
# 45454  False                                                NaN         0
# 45455  False                                                NaN         0
# 45456  False                                                NaN         0
# 45456  False                                                NaN         0
# 45456  False                                                NaN         0
# 45457  False                                                NaN         0
# 45457  False                                                NaN         0
# 45458  False                                                NaN         0
# 45459  False                                                NaN         0
# 45460  False                                                NaN         0
# 45460  False                                                NaN         0
# 45460  False                                                NaN         0
# 45461  False                                                NaN         0
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45463  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                            homepage      id    imdb_id  \
# 0              http://toystory.disney.com/toy-story     862  tt0114709
# 0              http://toystory.disney.com/toy-story     862  tt0114709
# 0              http://toystory.disney.com/toy-story     862  tt0114709
# 1                                               NaN    8844  tt0113497
# 1                                               NaN    8844  tt0113497
# 1                                               NaN    8844  tt0113497
# 2                                               NaN   15602  tt0113228
# 2                                               NaN   15602  tt0113228
# 3                                               NaN   31357  tt0114885
# 3                                               NaN   31357  tt0114885
# 3                                               NaN   31357  tt0114885
# 4                                               NaN   11862  tt0113041
# 5                                               NaN     949  tt0113277
# 5                                               NaN     949  tt0113277
# 5                                               NaN     949  tt0113277
# 5                                               NaN     949  tt0113277
# 6                                               NaN   11860  tt0114319
# 6                                               NaN   11860  tt0114319
# 7                                               NaN   45325  tt0112302
# 7                                               NaN   45325  tt0112302
# 7                                               NaN   45325  tt0112302
# 7                                               NaN   45325  tt0112302
# 8                                               NaN    9091  tt0114576
# 8                                               NaN    9091  tt0114576
# 8                                               NaN    9091  tt0114576
# 9      http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 9      http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 9      http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 10                                              NaN    9087  tt0112346
# 10                                              NaN    9087  tt0112346
# ...                                             ...     ...        ...
# 45450                                           NaN   49280  tt0135453
# 45450                                           NaN   49280  tt0135453
# 45450                                           NaN   49280  tt0135453
# 45451                                           NaN  106807  tt0135571
# 45451                                           NaN  106807  tt0135571
# 45452                                           NaN  276895  tt3054038
# 45453                                           NaN  404604  tt5690142
# 45453                                           NaN  404604  tt5690142
# 45453                                           NaN  404604  tt5690142
# 45454                                           NaN  420346  tt4130180
# 45454                                           NaN  420346  tt4130180
# 45455                                           NaN   67179  tt0069215
# 45456                                           NaN   84419  tt0038621
# 45456                                           NaN   84419  tt0038621
# 45456                                           NaN   84419  tt0038621
# 45457                                           NaN  390959  tt0265736
# 45457                                           NaN  390959  tt0265736
# 45458                                           NaN  289923  tt0252966
# 45459                                           NaN  222848  tt0112613
# 45460                                           NaN   30840  tt0102797
# 45460                                           NaN   30840  tt0102797
# 45460                                           NaN   30840  tt0102797
# 45461          http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45461          http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                           NaN  111109  tt2028550
# 45463                                           NaN   67758  tt0303758
# 45463                                           NaN   67758  tt0303758
# 45463                                           NaN   67758  tt0303758
# 45464                                           NaN  227506  tt0008536
# 45465                                           NaN  461257  tt6980792
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 0                    en                       Toy Story
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 1                    en                         Jumanji
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 3                    en               Waiting to Exhale
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# 5                    en                            Heat
# 5                    en                            Heat
# 5                    en                            Heat
# 5                    en                            Heat
# 6                    en                         Sabrina
# 6                    en                         Sabrina
# 7                    en                    Tom and Huck
# 7                    en                    Tom and Huck
# 7                    en                    Tom and Huck
# 7                    en                    Tom and Huck
# 8                    en                    Sudden Death
# 8                    en                    Sudden Death
# 8                    en                    Sudden Death
# 9                    en                       GoldenEye
# 9                    en                       GoldenEye
# 9                    en                       GoldenEye
# 10                   en          The American President
# 10                   en          The American President
# ...                 ...                             ...
# 45450                fr               L'Homme orchestre
# 45450                fr               L'Homme orchestre
# 45450                fr               L'Homme orchestre
# 45451                fr  Nouvelles luttes extravagantes
# 45451                fr  Nouvelles luttes extravagantes
# 45452                en                     Deep Hearts
# 45453                hi                             Maa
# 45453                hi                             Maa
# 45453                hi                             Maa
# 45454                en               The Morning After
# 45454                en               The Morning After
# 45455                it      San Michele aveva un gallo
# 45456                en                House of Horrors
# 45456                en                House of Horrors
# 45456                en                House of Horrors
# 45457                en       Shadow of the Blair Witch
# 45457                en       Shadow of the Blair Witch
# 45458                en             The Burkittsville 7
# 45459                en                 Caged Heat 3000
# 45460                en                      Robin Hood
# 45460                en                      Robin Hood
# 45460                en                      Robin Hood
# 45461                fa                         رگ خواب
# 45461                fa                         رگ خواب
# 45462                tl             Siglo ng Pagluluwal
# 45463                en                        Betrayal
# 45463                en                        Betrayal
# 45463                en                        Betrayal
# 45464                en             Satana likuyushchiy
# 45465                en                        Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# 5      Obsessive master thief, Neil McCauley leads a ...    17.9249
# 5      Obsessive master thief, Neil McCauley leads a ...    17.9249
# 5      Obsessive master thief, Neil McCauley leads a ...    17.9249
# 5      Obsessive master thief, Neil McCauley leads a ...    17.9249
# 6      An ugly duckling having undergone a remarkable...    6.67728
# 6      An ugly duckling having undergone a remarkable...    6.67728
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.56116
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.56116
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.56116
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.56116
# 8      International action superstar Jean Claude Van...    5.23158
# 8      International action superstar Jean Claude Van...    5.23158
# 8      International action superstar Jean Claude Van...    5.23158
# 9      James Bond must unmask the mysterious head of ...     14.686
# 9      James Bond must unmask the mysterious head of ...     14.686
# 9      James Bond must unmask the mysterious head of ...     14.686
# 10     Widowed U.S. president Andrew Shepherd, one of...    6.31844
# 10     Widowed U.S. president Andrew Shepherd, one of...    6.31844
# ...                                                  ...        ...
# 45450  A band-leader has arranged seven chairs for th...   1.109068
# 45450  A band-leader has arranged seven chairs for th...   1.109068
# 45450  A band-leader has arranged seven chairs for th...   1.109068
# 45451         A series of fantastical wrestling matches.   0.225432
# 45451         A series of fantastical wrestling matches.   0.225432
# 45452  Deep Hearts is a film about the Bororo Fulani,...   0.011025
# 45453  The bliss of a biology teacher’s family life i...   1.559596
# 45453  The bliss of a biology teacher’s family life i...   1.559596
# 45453  The bliss of a biology teacher’s family life i...   1.559596
# 45454  The Morning After is a feature film that consi...   0.139936
# 45454  The Morning After is a feature film that consi...   0.139936
# 45455  Sentenced to life imprisonment for illegal act...   0.225051
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45457  In this true-crime documentary, we delve into ...   0.076061
# 45457  In this true-crime documentary, we delve into ...   0.076061
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45461        Rising and falling between a man and woman.   0.072051
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#             ...        runtime  \
# 0           ...           81.0
# 0           ...           81.0
# 0           ...           81.0
# 1           ...          104.0
# 1           ...          104.0
# 1           ...          104.0
# 2           ...          101.0
# 2           ...          101.0
# 3           ...          127.0
# 3           ...          127.0
# 3           ...          127.0
# 4           ...          106.0
# 5           ...          170.0
# 5           ...          170.0
# 5           ...          170.0
# 5           ...          170.0
# 6           ...          127.0
# 6           ...          127.0
# 7           ...           97.0
# 7           ...           97.0
# 7           ...           97.0
# 7           ...           97.0
# 8           ...          106.0
# 8           ...          106.0
# 8           ...          106.0
# 9           ...          130.0
# 9           ...          130.0
# 9           ...          130.0
# 10          ...          106.0
# 10          ...          106.0
# ...         ...            ...
# 45450       ...            1.0
# 45450       ...            1.0
# 45450       ...            1.0
# 45451       ...            2.0
# 45451       ...            2.0
# 45452       ...           58.0
# 45453       ...          146.0
# 45453       ...          146.0
# 45453       ...          146.0
# 45454       ...           79.0
# 45454       ...           79.0
# 45455       ...           90.0
# 45456       ...           65.0
# 45456       ...           65.0
# 45456       ...           65.0
# 45457       ...           45.0
# 45457       ...           45.0
# 45458       ...           30.0
# 45459       ...           85.0
# 45460       ...          104.0
# 45460       ...          104.0
# 45460       ...          104.0
# 45461       ...           90.0
# 45461       ...           90.0
# 45462       ...          360.0
# 45463       ...           90.0
# 45463       ...           90.0
# 45463       ...           90.0
# 45464       ...           87.0
# 45465       ...           75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 6      [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 6      [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 7      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 7      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 7      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 7      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 8               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 10              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 10              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45450       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45450       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45450       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45451       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45451       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45452  [{'iso_639_1': 'ff', 'name': 'Fulfulde'}, {'is...  Released
# 45453            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 45453            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 45453            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 45454           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45454           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45455          [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 45456           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45456           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45456           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45457           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45457           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45458           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45459           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 0                                                    NaN
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 1              Roll the dice and unleash the excitement!
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 3      Friends are the people who let you be yourself...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# 5                               A Los Angeles Crime Saga
# 5                               A Los Angeles Crime Saga
# 5                               A Los Angeles Crime Saga
# 5                               A Los Angeles Crime Saga
# 6      You are cordially invited to the most surprisi...
# 6      You are cordially invited to the most surprisi...
# 7                                 The Original Bad Boys.
# 7                                 The Original Bad Boys.
# 7                                 The Original Bad Boys.
# 7                                 The Original Bad Boys.
# 8                             Terror goes into overtime.
# 8                             Terror goes into overtime.
# 8                             Terror goes into overtime.
# 9                   No limits. No fears. No substitutes.
# 9                   No limits. No fears. No substitutes.
# 9                   No limits. No fears. No substitutes.
# 10     Why can't the most powerful man in the world h...
# 10     Why can't the most powerful man in the world h...
# ...                                                  ...
# 45450                                                NaN
# 45450                                                NaN
# 45450                                                NaN
# 45451                                                NaN
# 45451                                                NaN
# 45452                                                NaN
# 45453                                                NaN
# 45453                                                NaN
# 45453                                                NaN
# 45454                          What happened last night?
# 45454                          What happened last night?
# 45455                                                NaN
# 45456                                Meet...The CREEPER!
# 45456                                Meet...The CREEPER!
# 45456                                Meet...The CREEPER!
# 45457                                                NaN
# 45457                                                NaN
# 45458  Do you know what happened 50 years before "The...
# 45459                                                NaN
# 45460                                                NaN
# 45460                                                NaN
# 45460                                                NaN
# 45461         Rising and falling between a man and woman
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45463                             A deadly game of wits.
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                                   title  video vote_average vote_count  year  \
# 0                             Toy Story  False          7.7     5415.0  1995
# 0                             Toy Story  False          7.7     5415.0  1995
# 0                             Toy Story  False          7.7     5415.0  1995
# 1                               Jumanji  False          6.9     2413.0  1995
# 1                               Jumanji  False          6.9     2413.0  1995
# 1                               Jumanji  False          6.9     2413.0  1995
# 2                      Grumpier Old Men  False          6.5       92.0  1995
# 2                      Grumpier Old Men  False          6.5       92.0  1995
# 3                     Waiting to Exhale  False          6.1       34.0  1995
# 3                     Waiting to Exhale  False          6.1       34.0  1995
# 3                     Waiting to Exhale  False          6.1       34.0  1995
# 4           Father of the Bride Part II  False          5.7      173.0  1995
# 5                                  Heat  False          7.7     1886.0  1995
# 5                                  Heat  False          7.7     1886.0  1995
# 5                                  Heat  False          7.7     1886.0  1995
# 5                                  Heat  False          7.7     1886.0  1995
# 6                               Sabrina  False          6.2      141.0  1995
# 6                               Sabrina  False          6.2      141.0  1995
# 7                          Tom and Huck  False          5.4       45.0  1995
# 7                          Tom and Huck  False          5.4       45.0  1995
# 7                          Tom and Huck  False          5.4       45.0  1995
# 7                          Tom and Huck  False          5.4       45.0  1995
# 8                          Sudden Death  False          5.5      174.0  1995
# 8                          Sudden Death  False          5.5      174.0  1995
# 8                          Sudden Death  False          5.5      174.0  1995
# 9                             GoldenEye  False          6.6     1194.0  1995
# 9                             GoldenEye  False          6.6     1194.0  1995
# 9                             GoldenEye  False          6.6     1194.0  1995
# 10               The American President  False          6.5      199.0  1995
# 10               The American President  False          6.5      199.0  1995
# ...                                 ...    ...          ...        ...   ...
# 45450                  The One-Man Band  False          6.5       22.0  1900
# 45450                  The One-Man Band  False          6.5       22.0  1900
# 45450                  The One-Man Band  False          6.5       22.0  1900
# 45451  The Fat and Lean Wrestling Match  False          6.5        6.0  1900
# 45451  The Fat and Lean Wrestling Match  False          6.5        6.0  1900
# 45452                       Deep Hearts  False          0.0        0.0  1981
# 45453                               Mom  False          6.6       14.0  2017
# 45453                               Mom  False          6.6       14.0  2017
# 45453                               Mom  False          6.6       14.0  2017
# 45454                 The Morning After  False          4.0        2.0  2015
# 45454                 The Morning After  False          4.0        2.0  2015
# 45455         St. Michael Had a Rooster  False          6.0        3.0  1972
# 45456                  House of Horrors  False          6.3        8.0  1946
# 45456                  House of Horrors  False          6.3        8.0  1946
# 45456                  House of Horrors  False          6.3        8.0  1946
# 45457         Shadow of the Blair Witch  False          7.0        2.0  2000
# 45457         Shadow of the Blair Witch  False          7.0        2.0  2000
# 45458               The Burkittsville 7  False          7.0        1.0  2000
# 45459                   Caged Heat 3000  False          3.5        1.0  1995
# 45460                        Robin Hood  False          5.7       26.0  1991
# 45460                        Robin Hood  False          5.7       26.0  1991
# 45460                        Robin Hood  False          5.7       26.0  1991
# 45461                            Subdue  False          4.0        1.0   NaT
# 45461                            Subdue  False          4.0        1.0   NaT
# 45462               Century of Birthing  False          9.0        3.0  2011
# 45463                          Betrayal  False          3.8        6.0  2003
# 45463                          Betrayal  False          3.8        6.0  2003
# 45463                          Betrayal  False          3.8        6.0  2003
# 45464                  Satan Triumphant  False          0.0        0.0  1917
# 45465                          Queerama  False          0.0        0.0  2017
#
#                  genre
# 0            Animation
# 0               Comedy
# 0               Family
# 1            Adventure
# 1              Fantasy
# 1               Family
# 2              Romance
# 2               Comedy
# 3               Comedy
# 3                Drama
# 3              Romance
# 4               Comedy
# 5               Action
# 5                Crime
# 5                Drama
# 5             Thriller
# 6               Comedy
# 6              Romance
# 7               Action
# 7            Adventure
# 7                Drama
# 7               Family
# 8               Action
# 8            Adventure
# 8             Thriller
# 9            Adventure
# 9               Action
# 9             Thriller
# 10              Comedy
# 10               Drama
# ...                ...
# 45450          Fantasy
# 45450           Action
# 45450         Thriller
# 45451           Comedy
# 45451          Fantasy
# 45452      Documentary
# 45453            Crime
# 45453            Drama
# 45453         Thriller
# 45454           Comedy
# 45454            Drama
# 45455              NaN
# 45456           Horror
# 45456          Mystery
# 45456         Thriller
# 45457          Mystery
# 45457           Horror
# 45458           Horror
# 45459  Science Fiction
# 45460            Drama
# 45460           Action
# 45460          Romance
# 45461            Drama
# 45461           Family
# 45462            Drama
# 45463           Action
# 45463            Drama
# 45463         Thriller
# 45464              NaN
# 45465              NaN
#
# [93548 rows x 25 columns]

# %%
def build_chart(genre,percentile=0.85):
    df = gen_md[gen_md['genre'] == genre]
    vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
    m = vote_counts.quantile(percentile)
    C = vote_averages.mean()
    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    
    qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(250)
    
    return qualified

# %%
build_chart('Romance')
# Out:
#                                        title  year  vote_count  vote_average  \
# 10309            Dilwale Dulhania Le Jayenge  1995         661             9
# 351                             Forrest Gump  1994        8147             8
# 876                                  Vertigo  1958        1162             8
# 40251                             Your Name.  2016        1030             8
# 883                         Some Like It Hot  1959         835             8
# 1132                         Cinema Paradiso  1988         834             8
# 19901                               Paperman  2012         734             8
# 37863                            Sing Street  2016         669             8
# 882                            The Apartment  1960         498             8
# 38718                         The Handmaiden  2016         453             8
# 3189                             City Lights  1931         444             8
# 24886                       The Way He Looks  2014         262             8
# 45437                         In a Heartbeat  2017         146             8
# 1639                                 Titanic  1997        7770             7
# 19731                Silver Linings Playbook  2012        4840             7
# 40882                             La La Land  2016        4745             7
# 23437                             Maleficent  2014        4607             7
# 22168                                    Her  2013        4215             7
# 20910                       The Great Gatsby  2013        3885             7
# 23512                 The Fault in Our Stars  2014        3868             7
# 7208   Eternal Sunshine of the Spotless Mind  2004        3758             7
# 2178                     Edward Scissorhands  1990        3731             7
# 581                                  Aladdin  1992        3495             7
# 4843                                  Amélie  2001        3403             7
# 24982               The Theory of Everything  2014        3403             7
# 13219    The Curious Case of Benjamin Button  2008        3398             7
# 11007                  The Devil Wears Prada  2006        3198             7
# 7834                            The Notebook  2004        3163             7
# 4865                        A Beautiful Mind  2001        3087             7
# 19460        The Perks of Being a Wallflower  2012        3056             7
# ...                                      ...   ...         ...           ...
# 33321                               Freeheld  2015         168             7
# 14418                        Broken Embraces  2009         167             7
# 7791                                La Jetée  1962         165             7
# 18170                                Weekend  2011         164             7
# 24805                              Free Fall  2013         164             7
# 2617                           Jules and Jim  1962         163             7
# 151                            Belle de Jour  1967         163             7
# 874                               Funny Face  1957         162             7
# 14428                                  Keith  2008         162             7
# 2728                    Black Cat, White Cat  1998         160             7
# 9323                           My Sassy Girl  2001         158             7
# 1143                            Mediterraneo  1991         157             7
# 1764                          Les Misérables  1998         157             7
# 7613           Sunrise: A Song of Two Humans  1927         155             7
# 35535             The Last: Naruto the Movie  2014         154             7
# 10920                                  Candy  2006         152             7
# 8979                          Only Yesterday  1991         152             7
# 1064                         Sophie's Choice  1982         149             7
# 1830             The Best Years of Our Lives  1946         148             7
# 3720                         Steel Magnolias  1989         146             7
# 3546                        Romeo and Juliet  1968         145             7
# 25050                      Beyond the Lights  2014         139             7
# 1835                   From Here to Eternity  1953         137             7
# 4727                     Fiddler on the Roof  1971         136             7
# 6882                            Show Me Love  1998         134             7
# 7582                  How to Steal a Million  1966         133             7
# 6912                    Beauty and the Beast  1946         133             7
# 24888                        Remember Sunday  2013         131             7
# 2801                               Body Heat  1981         128             7
# 11837            I'm a Cyborg, But That's OK  2006         126             7
#
#       popularity        wr
# 10309     34.457  8.565285
# 351      48.3072  7.971357
# 876      18.2082  7.811667
# 40251  34.461252  7.789489
# 883      11.8451  7.745154
# 1132      14.177  7.744878
# 19901    7.19863  7.713951
# 37863  10.672862  7.689483
# 882      11.9943  7.599317
# 38718  16.727405  7.566166
# 3189     10.8915  7.558867
# 24886    5.71127  7.331363
# 45437   20.82178  7.003959
# 1639     26.8891  6.981546
# 19731    14.4881  6.970581
# 40882  19.681686  6.970003
# 23437    19.4674  6.969122
# 22168    13.8295  6.966311
# 20910    17.5989  6.963515
# 23512    16.2747  6.963358
# 7208     12.9063  6.962311
# 2178     17.6122  6.962045
# 581      16.3574  6.959547
# 4843     12.8794  6.958481
# 24982     11.853  6.958481
# 13219    17.9348  6.958422
# 11007    13.1024  6.955893
# 7834      15.239  6.955419
# 4865     11.9365  6.954353
# 19460    12.7757  6.953903
# ...          ...       ...
# 33321   4.955317  6.439698
# 14418    6.77738  6.437526
# 7791     7.28266  6.433130
# 18170    4.72717  6.430906
# 24805    5.98915  6.430906
# 2617     5.97979  6.428664
# 151      10.1427  6.428664
# 874      5.46149  6.426405
# 14428    9.56091  6.426405
# 2728     6.26147  6.421833
# 9323      5.9805  6.417187
# 1143     5.55776  6.414836
# 1764     12.2385  6.414836
# 7613      4.2497  6.410077
# 35535   5.294086  6.407668
# 10920     4.7722  6.402791
# 8979     10.8318  6.402791
# 1064     15.4172  6.395323
# 1830     6.06934  6.392792
# 3720     7.14561  6.387665
# 3546     6.99099  6.385070
# 25050    6.29352  6.369021
# 1835     5.35858  6.363484
# 4727     9.22724  6.360678
# 6882     10.5834  6.354993
# 7582     12.3896  6.352112
# 6912     4.79885  6.352112
# 24888    11.1906  6.346273
# 2801     5.99148  6.337313
# 11837    4.36998  6.331203
#
# [250 rows x 6 columns]

# %% [markdown]
# ## Content Based Recommender

# %%
md['tagline'] = md['tagline'].fillna('')
md['description'] = md['tagline'] + md['overview']
md['description'] = md['description'].fillna('')
#md.head()

# %%
# tf = TfidfVectorizer(analyzer='word', ngram_range=(1,2), min_df=10, stop_words='english')
# tfidf_matrix = tf.fit_transform(md['description'])
# tfidf_matrix.shape

# %%
#cosine_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_similaritye_sim = linear_kernel(tfidf_matrix,tfidf_matrix)

# %%
links_small = pd.read_csv('the-movies-dataset/links_small.csv')
links_small = links_small[links_small['tmdbId'].notnull()]['tmdbId'].astype('int')
md = md.drop([19730, 29503, 35587])
md['id'] = md['id'].astype('int')
smd = md[md['id'].isin(links_small)]
smd.shape
# Out:
# (9099, 26)

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,2), min_df=10,stop_words='english')
tfidf_matrix = tf.fit_transform(smd['description'])
tfidf_matrix.shape
# Out:
# (9099, 5161)

# %%
cosine_sim = linear_kernel(tfidf_matrix,tfidf_matrix)

# %%
smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('Aladdin')
# Out:
# 24351                                     John Wick
# 23245                               The Other Woman
# 4368                                         D.O.A.
# 4574                                       Chocolat
# 1846                              Kramer vs. Kramer
# 4095                                       C.H.U.D.
# 2874                                Licence to Kill
# 807                                       Stonewall
# 19821                                      10 Years
# 32385                                  10 Attitudes
# 8345                             She Done Him Wrong
# 6163                                     Straw Dogs
# 2804                           Children of Paradise
# 208                            The Browning Version
# 3347                                            Hud
# 962                                    Maximum Risk
# 4949                                       Slackers
# 10360                                       Go West
# 2974                                      Kagemusha
# 4934                      The Count of Monte Cristo
# 6865                                   Passenger 57
# 7621                                The Inheritance
# 8194                                The Rose Tattoo
# 2498                                 Mildred Pierce
# 7824                            My Little Chickadee
# 2170                             The Sheltering Sky
# 4088     Revenge of the Nerds II: Nerds in Paradise
# 2810                                      Hairspray
# 4162                                   For the Boys
# 15481                                     Grown Ups
# Name: title, dtype: object

# %% [markdown]
# # Recommendation as per the Cast,Director,Genres and Keywords

# %%
credits = pd.read_csv('the-movies-dataset/credits.csv')
keywords = pd.read_csv('the-movies-dataset/keywords.csv')

# %%
credits['id'] = credits['id'].astype('int')
keywords['id'] = keywords['id'].astype('int')
md['id'] = md['id'].astype('int')

# %%
md = md.merge(credits,on='id')
md = md.merge(keywords,on='id')
smd = md[md['id'].isin(links_small)]
smd.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                              tagline  \
# 0
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year  \
# 0                    Toy Story  False          7.7     5415.0  1995
# 1                      Jumanji  False          6.9     2413.0  1995
# 2             Grumpier Old Men  False          6.5       92.0  1995
# 3            Waiting to Exhale  False          6.1       34.0  1995
# 4  Father of the Bride Part II  False          5.7      173.0  1995
#
#                                          description  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  Roll the dice and unleash the excitement!When ...
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
# [5 rows x 29 columns]

# %%
smd.head().transpose()
# Out:
#                                                                        0  \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                                       [Animation, Comedy, Family]
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.9469
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# production_companies      [{'name': 'Pixar Animation Studios', 'id': 3}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-10-30
# revenue                                                      3.73554e+08
# runtime                                                               81
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline
# title                                                          Toy Story
# video                                                              False
# vote_average                                                         7.7
# vote_count                                                          5415
# year                                                                1995
# description            Led by Woody, Andy's toys live happily in his ...
# cast                   [{'cast_id': 14, 'character': 'Woody (voice)',...
# crew                   [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# keywords               [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
#
#                                                                        1  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                                      [Adventure, Fantasy, Family]
# homepage                                                             NaN
# id                                                                  8844
# imdb_id                                                        tt0113497
# original_language                                                     en
# original_title                                                   Jumanji
# overview               When siblings Judy and Peter discover an encha...
# popularity                                                       17.0155
# poster_path                             /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# production_companies   [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-15
# revenue                                                      2.62797e+08
# runtime                                                              104
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                        Roll the dice and unleash the excitement!
# title                                                            Jumanji
# video                                                              False
# vote_average                                                         6.9
# vote_count                                                          2413
# year                                                                1995
# description            Roll the dice and unleash the excitement!When ...
# cast                   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# crew                   [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# keywords               [{'id': 10090, 'name': 'board game'}, {'id': 1...
#
#                                                                        2  \
# adult                                                              False
# belongs_to_collection  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                 0
# genres                                                 [Romance, Comedy]
# homepage                                                             NaN
# id                                                                 15602
# imdb_id                                                        tt0113228
# original_language                                                     en
# original_title                                          Grumpier Old Men
# overview               A family wedding reignites the ancient feud be...
# popularity                                                       11.7129
# poster_path                             /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                                0
# runtime                                                              101
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# video                                                              False
# vote_average                                                         6.5
# vote_count                                                            92
# year                                                                1995
# description            Still Yelling. Still Fighting. Still Ready for...
# cast                   [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# crew                   [{'credit_id': '52fe466a9251416c75077a89', 'de...
# keywords               [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
#
#                                                                        3  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          16000000
# genres                                          [Comedy, Drama, Romance]
# homepage                                                             NaN
# id                                                                 31357
# imdb_id                                                        tt0114885
# original_language                                                     en
# original_title                                         Waiting to Exhale
# overview               Cheated on, mistreated and stepped on, the wom...
# popularity                                                       3.85949
# poster_path                             /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# production_companies   [{'name': 'Twentieth Century Fox Film Corporat...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                      8.14522e+07
# runtime                                                              127
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Friends are the people who let you be yourself...
# title                                                  Waiting to Exhale
# video                                                              False
# vote_average                                                         6.1
# vote_count                                                            34
# year                                                                1995
# description            Friends are the people who let you be yourself...
# cast                   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# crew                   [{'credit_id': '52fe44779251416c91011acb', 'de...
# keywords               [{'id': 818, 'name': 'based on novel'}, {'id':...
#
#                                                                        4
# adult                                                              False
# belongs_to_collection  {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                 0
# genres                                                          [Comedy]
# homepage                                                             NaN
# id                                                                 11862
# imdb_id                                                        tt0113041
# original_language                                                     en
# original_title                               Father of the Bride Part II
# overview               Just when George Banks has recovered from his ...
# popularity                                                       8.38752
# poster_path                             /e64sOI48hQXyru7naBFyssKFxVd.jpg
# production_companies   [{'name': 'Sandollar Productions', 'id': 5842}...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-02-10
# revenue                                                      7.65789e+07
# runtime                                                              106
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Just When His World Is Back To Normal... He's ...
# title                                        Father of the Bride Part II
# video                                                              False
# vote_average                                                         5.7
# vote_count                                                           173
# year                                                                1995
# description            Just When His World Is Back To Normal... He's ...
# cast                   [{'cast_id': 1, 'character': 'George Banks', '...
# crew                   [{'credit_id': '52fe44959251416c75039ed7', 'de...
# keywords               [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
smd['cast'] = smd['cast'].apply(ast.literal_eval)
smd['crew'] = smd['crew'].apply(ast.literal_eval)
smd['keywords'] = smd['keywords'].apply(ast.literal_eval)
smd['cast_size'] = smd['cast'].apply(lambda x: len(x))
smd['crew_size'] = smd['crew'].apply(lambda x: len(x))
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']

# %%
smd['director'] = smd['crew'].apply(get_director)
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
smd['cast'] = smd['cast'].apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else [])
smd['cast'] = smd['cast'].apply(lambda x: x[:3] if len(x)>=3 else x)
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# smd = smd.drop('cast',axis=1)
# smd['cast']

# %%
smd['director'] = smd['director'].astype('str').apply(lambda x: str.lower(x.replace(' ','')))
smd['director'] = smd['director'].apply(lambda x: [x,x,x])
#smd['director']
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
smd['cast'] = smd['cast'].astype('str').apply(lambda x: [str.lower(i.replace(' ','') ) for i in x])
smd['keywords'] = smd['keywords'].apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else [])
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
stemmer = SnowballStemmer('english')
smd['keywords2'] = smd['keywords'].apply(lambda x: [stemmer.stem(i) for i in x])
smd['keywords2'] = smd['keywords2'].apply(lambda x: [str.lower(i.replace(' ','')) for i in x])
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
smd['soup'] = smd['keywords2'] + smd['cast'] + smd['director'] + smd['genres']
smd['soup'] = smd['soup'].apply(lambda x: ' '.join(x))
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
count_matrix = count.fit_transform(smd['soup'])

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
get_recommendations('Mean Girls').head(10)
# Out:
# 3319               Head Over Heels
# 1329              The House of Yes
# 6277              Just Like Heaven
# 7332    Ghosts of Girlfriends Past
# 4763                 Freaky Friday
# 7905         Mr. Popper's Penguins
# 6959     The Spiderwick Chronicles
# 8883                      The DUFF
# 6698         It's a Boy Girl Thing
# 3712          The Princess Diaries
# Name: title, dtype: object

# %% [markdown]
# Popularity and Ratings
# One thing that we notice about our recommendation system is that it recommends movies regardless of ratings and popularity. It is true that Batman and Robin has a lot of similar characters as compared to The Dark Knight but it was a terrible movie that shouldn't be recommended to anyone.
#
# Therefore, we will add a mechanism to remove bad movies and return movies which are popular and have had a good critical response.
#
# I will take the top 25 movies based on similarity scores and calculate the vote of the 60th percentile movie. Then, using this as the value of  m , we will calculate the weighted rating of each movie using IMDB's formula like we did in the Simple Recommender section.

# %%
def improved_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year']]
    vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(0.60)
    qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
improved_recommendations('Shutter Island')
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                         title  vote_count  vote_average  year        wr
# 986                GoodFellas        3211             8  1990  7.671958
# 101               Taxi Driver        2632             8  1976  7.610008
# 8544  The Wolf of Wall Street        6768             7  2013  6.894236
# 6599             The Departed        4455             7  2006  6.844198
# 4439        Gangs of New York        1964             7  2002  6.682354
# 6047              The Aviator        1526             7  2004  6.611370
# 15                     Casino        1343             7  1995  6.571348
# 1001              Raging Bull         968             7  1980  6.456694
# 1104                Cape Fear         692             7  1991  6.323521
# 5376             Mean Streets         359             7  1973  6.039452

# %%
def more_improved_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:70]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year']]
    vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(0.60)
    qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
more_improved_recommendations('Shutter Island')
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                                     title  vote_count  vote_average  year  \
# 986                            GoodFellas        3211             8  1990
# 101                           Taxi Driver        2632             8  1976
# 8544              The Wolf of Wall Street        6768             7  2013
# 6599                         The Departed        4455             7  2006
# 7186  The Curious Case of Benjamin Button        3398             7  2008
# 8007                                 Hugo        2197             7  2011
# 4439                    Gangs of New York        1964             7  2002
# 1311                             The Game        1556             7  1997
# 6047                          The Aviator        1526             7  2004
# 15                                 Casino        1343             7  1995
#
#             wr
# 986   7.671958
# 101   7.610008
# 8544  6.894236
# 6599  6.844198
# 7186  6.801223
# 8007  6.710485
# 4439  6.682354
# 1311  6.617229
# 6047  6.611370
# 15    6.571348

# %% [markdown]
# ## Collaborative Filtering
#
# Our content based engine suffers from some severe limitations. It is only capable of suggesting movies which are close to a certain movie. That is, it is not capable of capturing tastes and providing recommendations across genres.
#
# Also, the engine that we built is not really personal in that it doesn't capture the personal tastes and biases of a user. Anyone querying our engine for recommendations based on a movie will receive the same recommendations for that movie, regardless of who s/he is.
#
# Therefore, in this section, we will use a technique called Collaborative Filtering to make recommendations to Movie Watchers. Collaborative Filtering is based on the idea that users similar to a me can be used to predict how much I will like a particular product or service those users have used/experienced but I have not.
#
# I will not be implementing Collaborative Filtering from scratch. Instead, I will use the Surprise library that used extremely powerful algorithms like Singular Value Decomposition (SVD) to minimise RMSE (Root Mean Square Error) and give great recommendations.

# %%
reader = Reader()

# %%
ratings = pd.read_csv('the-movies-dataset/ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
data = Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)
data.split(n_folds=5)

# %%
svd = SVD()
evaluate(svd,data,measures=['RMSE','MAE'])
# Out:
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/surprise/evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# /home/vinove/Documents/Jupyter/lib/python3.5/site-packages/surprise/dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9044
# MAE:  0.6972
# ------------
# Fold 2
# RMSE: 0.8971
# MAE:  0.6905
# ------------
# Fold 3
# RMSE: 0.8918
# MAE:  0.6863
# ------------
# Fold 4
# RMSE: 0.8988
# MAE:  0.6929
# ------------
# Fold 5
# RMSE: 0.8881
# MAE:  0.6834
# ------------
# ------------
# Mean RMSE: 0.8960
# Mean MAE : 0.6901
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [0.6972060051065438,
#                              0.6905310111005176,
#                              0.6863209073545354,
#                              0.6928984415555001,
#                              0.6833763865838418],
#                             'rmse': [0.904413646593421,
#                              0.897127167485332,
#                              0.891801510369516,
#                              0.8987635326082835,
#                              0.8881395729375112]})

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
svd.predict(1, 302)
# Out:
# Prediction(uid=1, iid=302, r_ui=None, est=2.731207717877994, details={'was_impossible': False})

# %% [markdown]
# # Hybrid Recommender
# Merging Collebrative filtering with Content Based Recommender

# %%
def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
id_map = pd.read_csv('the-movies-dataset/links.csv')[['movieId', 'tmdbId']]
id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)
id_map.columns = ['movieId', 'id']
id_map = id_map.merge(smd[['title', 'id']], on='id').set_index('title')
id_map.head()
# Out:
#                              movieId       id
# title
# Toy Story                          1    862.0
# Jumanji                            2   8844.0
# Grumpier Old Men                   3  15602.0
# Waiting to Exhale                  4  31357.0
# Father of the Bride Part II        5  11862.0

# %%
indeces_map = id_map.set_index('id')

# %%
def hybrid_algo(user_id,title):
    idx = indeces[title]
    tmbdId = id_map.loc[title]['id']
    movieId = id_map.loc[title]['movieId']
    
    sim_score = list(enumerate(cosine_sim[int(idx)]))
    sim_score = sorted(sim_score,key=lambda x:x[1],reverse=True)
    sim_score = sim_score[1:26]
    
    movie_indeces = [i[0] for i in sim_score]
    movies = smd.iloc[movie_indeces][['title', 'vote_count', 'vote_average', 'year', 'id']]
    movies['est'] = movies['id'].apply(lambda x: svd.predict(user_id,indeces_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est',ascending=False)
    
    return movies.head(10)

# %%
hybrid_algo(1,'Avatar')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-132-da40f882b4a3> in <module>()
# ----> 1 hybrid_algo(1,'Avatar')
#
# <ipython-input-130-66e7305cf469> in hybrid_algo(user_id, title)
#       4     movieId = id_map.loc[title]['movieId']
#       5
# ----> 6     sim_score = list(enumerate(cosine_sim[int(idx)]))
#       7     sim_score = sorted(sim_score,key=lambda x:x[1],reverse=True)
#       8     sim_score = sim_score[1:26]
#
# IndexError: index 14551 is out of bounds for axis 0 with size 9219
